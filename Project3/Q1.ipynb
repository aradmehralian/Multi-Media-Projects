# %% [markdown]
# # Question 1
# ## Shape Detection

# %%
from src.functions2 import detect_and_label_shapes , remove_non_quadrilaterals
from src.functions import imshow , imread

# %%
image = imread('images/Shapes.jpg')
labeled_image = detect_and_label_shapes(image.copy())

# %%
imshow(labeled_image,"Labeled Shapes")

# %%
quadrilaterals_image = remove_non_quadrilaterals(image.copy())

# %%
imshow(quadrilaterals_image,"Quadrilaterals Only")
